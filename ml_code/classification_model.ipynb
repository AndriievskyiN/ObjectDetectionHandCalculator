# %%
import os

sets = ["train", "test"]
class_names = os.listdir("data/train")

for set_ in sets:
    for i in class_names:
        os.system(f"mkdir data/{set_}/{i}/images data/{set_}/{i}/labels")

# %%
import json
import matplotlib.pyplot as plt
import cv2

# %%
img_path = "data/train/two/images/0dd2b1e8-7261-432d-ba3e-fe3ca7224064.jpeg"
img = plt.imread(img_path)

# %%
plt.imshow(img);

# %%
with open("data/train/two/labels/0dd2b1e8-7261-432d-ba3e-fe3ca7224064.json", "r") as f:
    handle = f.read()
    file = json.loads(handle)
# Out:
# 4.5.12

# %%
detected = file["shapes"][0]["points"]
detected
# Out:
# [[650.1395348837209, 3.0], [897.8139534883721, 233.2325581395349]]

# %%
plt.imshow(img[3:233, 650: 897, :]);
